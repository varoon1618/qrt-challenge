# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sksurv.ensemble import RandomSurvivalForest
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.metrics import concordance_index_censored , concordance_index_ipcw
from sklearn.impute import SimpleImputer
from sksurv.util import Surv

# %%
df = pd.read_csv(".\X_train\clinical_train.csv")
gene_df = pd.read_csv('.\X_train\molecular_train.csv')
target_df = pd.read_csv('target_train.csv')

# %%
df['ID'] = df['ID'].astype(str)
gene_df['ID'] = gene_df['ID'].astype(str)

# %%
temp = df.merge(gene_df,how='left',on=['ID'])

# %%
temp = temp[['ID', 'EFFECT']]

# Crosstab -> ID as index
wide = pd.crosstab(temp['ID'], temp['EFFECT'])

# Convert to binary
wide = (wide > 0).astype(int)

# Reindex to include ALL IDs from df
wide = wide.reindex(df['ID'], fill_value=0)

# Now bring ID back as a column (only once)
wide = wide.reset_index()

# %%
wide.columns.tolist()
# Out:
# ['ID',
#  '2KB_upstream_variant',
#  '3_prime_UTR_variant',
#  'ITD',
#  'PTD',
#  'complex_change_in_transcript',
#  'frameshift_variant',
#  'inframe_codon_gain',
#  'inframe_codon_loss',
#  'inframe_variant',
#  'initiator_codon_change',
#  'non_synonymous_codon',
#  'splice_site_variant',
#  'stop_gained',
#  'stop_lost',
#  'stop_retained_variant',
#  'synonymous_codon']

# %%
cols = ['2KB_upstream_variant',
 '3_prime_UTR_variant',
 'ITD',
 'PTD',
 'complex_change_in_transcript',
 'frameshift_variant',
 'inframe_codon_gain',
 'inframe_codon_loss',
 'inframe_variant',
 'initiator_codon_change',
 'non_synonymous_codon',
 'splice_site_variant',
 'stop_gained',
 'stop_lost',
 'stop_retained_variant',
 'synonymous_codon']

# %%
# Drop rows where 'OS_YEARS' is NaN if conversion caused any issues
target_df.dropna(subset=['OS_YEARS', 'OS_STATUS'], inplace=True)

# Check the data types to ensure 'OS_STATUS' is boolean and 'OS_YEARS' is numeric
print(target_df[['OS_STATUS', 'OS_YEARS']].dtypes)

# Contarget_dfvert 'OS_YEARS' to numeric if it isn’t already
target_df['OS_YEARS'] = pd.to_numeric(target_df['OS_YEARS'], errors='coerce')

# Ensure 'OS_STATUS' is boolean
target_df['OS_STATUS'] = target_df['OS_STATUS'].astype(bool)
# Out:
# OS_STATUS    float64
# OS_YEARS     float64
# dtype: object

# %%
X = wide.loc[wide['ID'].isin(target_df['ID'])]
y = Surv.from_dataframe('OS_STATUS', 'OS_YEARS', target_df)

# %%
X['EFFECT_VECTOR'] = X[cols].values.tolist()
# Out:
# C:\Users\sheno\AppData\Local\Temp\ipykernel_14012\1589078377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['EFFECT_VECTOR'] = X[cols].values.tolist()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
target_df.columns.tolist()
# Out:
# ['ID', 'OS_YEARS', 'OS_STATUS']

# %%
temp = X_train.merge(target_df,how='inner',on=['ID'])
print(temp.shape)
print(X_train.shape)
# Out:
# (2221, 20)
# (2221, 18)

# %%
import numpy as np
ref = np.array([0]*16)
dead = temp[temp['OS_STATUS'] == 1]
c = 0
for effect in dead['EFFECT_VECTOR']:
    c+=1
    ref += np.array(effect)

ref = ref/c

# %%
def cosine_sim(effect,reference):
    effect_arr = np.array(effect)
    s = np.dot(effect_arr,reference)
    mag1 = np.linalg.norm(effect_arr)
    mag2 = np.linalg.norm(reference)
    if mag1*mag2 == 0:
        return 0.0
    norm = s/(mag1*mag2)
    return norm

X_train["EFFECT_DISTANCE"] = X_train["EFFECT_VECTOR"].apply(lambda v: cosine_sim(v,ref))

features = ["BM_BLAST","WBC","HB","PLT","PERCENT_ABNORMAL",'DELETIONS','INVERSIONS','MONOSOMY','IS_COMPLEX',"EFFECT_DISTANCE"]

X_train = X_train[features]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 15
#      11 X_train["EFFECT_DISTANCE"] = X_train["EFFECT_VECTOR"].apply(lambda v: cosine_sim(v,ref))
#      13 features = ["BM_BLAST","WBC","HB","PLT","PERCENT_ABNORMAL",'DELETIONS','INVERSIONS','MONOSOMY','IS_COMPLEX',"EFFECT_DISTANCE"]
# ---> 15 X_train = X_train[features]
#
# File ~\Downloads\soton_y3\challenge\VENV\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\Downloads\soton_y3\challenge\VENV\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
# ...

# %%
from sksurv.ensemble import RandomSurvivalForest
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.metrics import concordance_index_censored , concordance_index_ipcw
from sklearn.impute import SimpleImputer
from sksurv.util import Surv

cox = CoxPHSurvivalAnalysis()
cox.fit(X_train, y_train)

# Evaluate the model using Concordance Index IPCW
cox_cindex_train = concordance_index_ipcw(y_train, y_train, cox.predict(X_train), tau=7)[0]
#cox_cindex_test = concordance_index_ipcw(y_train, y_test, cox.predict(X_test), tau=7)[0]
print(f"Cox Proportional Hazard Model Concordance Index IPCW on train: {cox_cindex_train:.2f}")
#print(f"Cox Proportional Hazard Model Concordance Index IPCW on test: {cox_cindex_test:.2f}")
# Out:
# C:\Users\sheno\Downloads\soton_y3\challenge\VENV\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\sheno\Downloads\soton_y3\challenge\VENV\Lib\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The CoxPHSurvivalAnalysis or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ...

# %%
# Out:
# C:\Users\sheno\Downloads\soton_y3\challenge\VENV\Lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\sheno\Downloads\soton_y3\challenge\VENV\Lib\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The CoxnetSurvivalAnalysis or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# ...

# %%
coefs = pd.Series(cox_lasso.coef_[:, 0], index=features)
selected_features = coefs[coefs != 0].index.tolist()
print("Selected mutations:", selected_features)
# Out:
# Selected mutations: []
